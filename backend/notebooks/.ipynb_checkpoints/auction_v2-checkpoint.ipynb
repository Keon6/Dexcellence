# %%
import importlib
import os

os.chdir('/code')

from auction_engine import engine
from auction_engine.one_inch import get_reference_rate
from tests.utils import generate_limit_orders

importlib.reload(engine)
# Out:
# <module 'auction_engine.engine' from '/code/auction_engine/engine.py'>

# %%
# Auction parameters:
from_token = 'ETH'
to_token = 'USDT'

# %%
reference_rate = get_reference_rate(from_token, to_token, amount=1)
reference_rate
# Out:
# ReferenceRate(1231.88678 USDT/ETH)

# %%
num_buys = 4000
num_sells = 4000

buy_gen = range(num_buys)
sell_gen = range(num_buys, num_buys + num_sells)

buy_orders = generate_limit_orders(
    order_id_generator=buy_gen,
    wallet_id_generator=buy_gen,
    from_token=from_token,
    to_token=to_token,
    base_rate=reference_rate,
)
sell_orders = generate_limit_orders(
    order_id_generator=sell_gen,
    wallet_id_generator=sell_gen,
    from_token=to_token,
    to_token=from_token,
    base_rate=reference_rate,
)
all_orders = buy_orders + sell_orders

# %%
auction = engine.Auction(
    from_token=from_token,
    to_token=to_token,
    orders=all_orders,
)
auction_result = auction.run()
# Out:
# 2022-06-26 03:49:37 INFO     Starting auction
# 2022-06-26 03:49:37 INFO     Compiling order book data
# 2022-06-26 03:49:37 INFO     Constructing optimization problem
# 2022-06-26 03:49:47 INFO     Optimizing
# 2022-06-26 03:49:59 INFO     Validating clearing_rate 1232.1648135069654 with 1inch
# 2022-06-26 03:49:59 INFO     Updating the order book
# 2022-06-26 03:49:59 INFO     Compiling transactions

# %%
len(auction_result.transactions)
# Out:
# 8000

# %%
auction.plot_order_book(
    reference_rate=reference_rate.rate,
    clearing_rate=auction_result.clearing_rate,
)
# Out:
# 2022-06-26 03:50:43 INFO     Compiling order book data
# <AxesSubplot:title={'center':'Auction Order Book ETH/USDT'}, xlabel='amount', ylabel='limit_rate'>

# %%
auction.order_book.groupby('side')[['optimal_fill', 'standard_amount']].sum()
# Out:
#       optimal_fill  standard_amount
# side
# BUY    4967.636543          1995182
# SELL   4967.636543          1989160
